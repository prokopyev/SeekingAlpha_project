# %%
import numpy as np

import requests
from bs4 import BeautifulSoup
import time

from user_agent import generate_user_agent

# %%
import socks
import socket
socks.set_default_proxy(socks.SOCKS5, "localhost", 9150)
socket.socket = socks.socksocket

# %%
def checkIP():
    ip = requests.get('http://checkip.dyndns.org').content
    soup = BeautifulSoup(ip, 'html.parser')
    print(soup.find('body').text)

checkIP()
# Out:
# Current IP Address: 51.15.64.212

# %%
url_art = 'https://seekingalpha.com/earnings/earnings-call-transcripts/'  # + number
url_site = 'https://seekingalpha.com/'

folder = '../'

# %%
def transcript_links_getter(url_art, num_page):
    h = generate_user_agent() #next(headers)
    page = requests.get(url_art + str(num_page), headers={'User-Agent': h})
    page_bs = BeautifulSoup(page.text, "lxml")
    links = page_bs.findAll('ul', id='analysis-list-container')[0]
    links = links.findAll('h3')
    arts = []
    for a in links:
        arts.append(a.findAll('a')[0]['href'])
    return arts

# %%
def one_transcript_getter(art):
    h = generate_user_agent() #next(headers)
    page_art = requests.get(url_site + art, headers={'User-Agent': h})
    if page_art.status_code==200:
        page_bs_art = BeautifulSoup(page_art.text, "lxml")
        text = page_bs_art.findAll('article')[0]
        return text    
    else:
        try:
            time.sleep(np.random.uniform(low=3, high=5))
            page_art = requests.get(url_site + art, headers={'User-Agent': h})
            page_bs_art = BeautifulSoup(page_art.text, "lxml")
            text = page_bs_art.findAll('article')[0]
            return text
        except:
            with open(folder + "data/errors.txt", "a") as f:
                f.write(art)

# %%
for i in range(3329, 4565):
    print(i)
    time.sleep(np.random.uniform(low=11, high=12))
    arts = transcript_links_getter(url_art, i)
    for x in range(0, len(arts)):
        time.sleep(np.random.uniform(low=11, high=12))
        art_text = one_transcript_getter(arts[x])
        
        with open(folder + "data/parsing/" + str(i) + '_num_' + str(x) + '.txt', "w") as f:
            f.write(str(art_text))

        print(str(i) + '_num_' + str(x) + '.txt')
        #checkIP()
# Out:
# 3329
# 3329_num_0.txt
# 3329_num_1.txt
# 3329_num_2.txt
# 3329_num_3.txt
# 3329_num_4.txt
# 3329_num_5.txt
# 3329_num_6.txt
# 3329_num_7.txt
# 3329_num_8.txt
# 3329_num_9.txt
# 3329_num_10.txt
# 3329_num_11.txt
# 3329_num_12.txt
# 3329_num_13.txt
# 3329_num_14.txt
# 3329_num_15.txt
# 3329_num_16.txt
# 3329_num_17.txt
# 3329_num_18.txt
# 3329_num_19.txt
# 3329_num_20.txt
# 3329_num_21.txt
# 3329_num_22.txt
# 3329_num_23.txt
# 3329_num_24.txt
# 3329_num_25.txt
# 3329_num_26.txt
# 3329_num_27.txt
# 3329_num_28.txt
# 3329_num_29.txt
# 3330
# 3330_num_0.txt
# 3330_num_1.txt
# 3330_num_2.txt
# 3330_num_3.txt
# 3330_num_4.txt
# 3330_num_5.txt
# 3330_num_6.txt
# 3330_num_7.txt
# 3330_num_8.txt
# 3330_num_9.txt
# 3330_num_10.txt
# 3330_num_11.txt
# 3330_num_12.txt
# 3330_num_13.txt
# 3330_num_14.txt
# 3330_num_15.txt
# 3330_num_16.txt
# 3330_num_17.txt
# 3330_num_18.txt
# 3330_num_19.txt
# 3330_num_20.txt
# 3330_num_21.txt
# 3330_num_22.txt
# 3330_num_23.txt
# 3330_num_24.txt
# 3330_num_25.txt
# 3330_num_26.txt
# 3330_num_27.txt
# 3330_num_28.txt
# 3330_num_29.txt
# 3331
# 3331_num_0.txt
# 3331_num_1.txt
# 3331_num_2.txt
# 3331_num_3.txt
# 3331_num_4.txt
# 3331_num_5.txt
# 3331_num_6.txt
# 3331_num_7.txt
# 3331_num_8.txt
# 3331_num_9.txt
# 3331_num_10.txt
# 3331_num_11.txt
# 3331_num_12.txt
# 3331_num_13.txt
# 3331_num_14.txt
# 3331_num_15.txt
# 3331_num_16.txt
# 3331_num_17.txt
# 3331_num_18.txt
# 3331_num_19.txt
# 3331_num_20.txt
# 3331_num_21.txt
# 3331_num_22.txt
# 3331_num_23.txt
# 3331_num_24.txt
# 3331_num_25.txt
# 3331_num_26.txt
# 3331_num_27.txt
# 3331_num_28.txt
# 3331_num_29.txt
# 3332
# 3332_num_0.txt
# 3332_num_1.txt
# 3332_num_2.txt
# 3332_num_3.txt
# 3332_num_4.txt
# 3332_num_5.txt
# 3332_num_6.txt
# 3332_num_7.txt
# 3332_num_8.txt
# 3332_num_9.txt
# 3332_num_10.txt
# 3332_num_11.txt
# 3332_num_12.txt
# 3332_num_13.txt
# 3332_num_14.txt
# 3332_num_15.txt
# 3332_num_16.txt
# 3332_num_17.txt
# 3332_num_18.txt
# 3332_num_19.txt
# 3332_num_20.txt
# 3332_num_21.txt
# 3332_num_22.txt
# 3332_num_23.txt
# 3332_num_24.txt
# 3332_num_25.txt
# 3332_num_26.txt
# 3332_num_27.txt
# 3332_num_28.txt
# 3332_num_29.txt
# 3333
# 3333_num_0.txt
# 3333_num_1.txt
# 3333_num_2.txt
# 3333_num_3.txt
# 3333_num_4.txt
# 3333_num_5.txt
# 3333_num_6.txt
# 3333_num_7.txt
# 3333_num_8.txt
# 3333_num_9.txt
# 3333_num_10.txt
# 3333_num_11.txt
# 3333_num_12.txt
# 3333_num_13.txt
# 3333_num_14.txt
# 3333_num_15.txt
# 3333_num_16.txt
# 3333_num_17.txt
# 3333_num_18.txt
# 3333_num_19.txt
# 3333_num_20.txt
# 3333_num_21.txt
# 3333_num_22.txt
# 3333_num_23.txt
# 3333_num_24.txt
# 3333_num_25.txt
# 3333_num_26.txt
# 3333_num_27.txt
# 3333_num_28.txt
# 3333_num_29.txt
# 3334
# 3334_num_0.txt
# 3334_num_1.txt
# 3334_num_2.txt
# 3334_num_3.txt
# 3334_num_4.txt
# 3334_num_5.txt
# 3334_num_6.txt
# 3334_num_7.txt
# 3334_num_8.txt
# 3334_num_9.txt
# 3334_num_10.txt
# 3334_num_11.txt
# 3334_num_12.txt
# 3334_num_13.txt
# 3334_num_14.txt
# 3334_num_15.txt
# 3334_num_16.txt
# 3334_num_17.txt
# 3334_num_18.txt
# 3334_num_19.txt
# 3334_num_20.txt
# 3334_num_21.txt
# 3334_num_22.txt
# 3334_num_23.txt
# 3334_num_24.txt
# 3334_num_25.txt
# 3334_num_26.txt
# 3334_num_27.txt
# 3334_num_28.txt
# 3334_num_29.txt
# 3335
# 3335_num_0.txt
# 3335_num_1.txt
# 3335_num_2.txt
# 3335_num_3.txt
# 3335_num_4.txt
# 3335_num_5.txt
# 3335_num_6.txt
# 3335_num_7.txt
# 3335_num_8.txt
# 3335_num_9.txt
# 3335_num_10.txt
# 3335_num_11.txt
# 3335_num_12.txt
# 3335_num_13.txt
# 3335_num_14.txt
# 3335_num_15.txt
# 3335_num_16.txt
# 3335_num_17.txt
# 3335_num_18.txt
# 3335_num_19.txt
# 3335_num_20.txt
# 3335_num_21.txt
# 3335_num_22.txt
# 3335_num_23.txt
# 3335_num_24.txt
# 3335_num_25.txt
# 3335_num_26.txt
# 3335_num_27.txt
# 3335_num_28.txt
# 3335_num_29.txt
# 3336
# 3336_num_0.txt
# 3336_num_1.txt
# 3336_num_2.txt
# 3336_num_3.txt
# 3336_num_4.txt
# 3336_num_5.txt
# 3336_num_6.txt
# 3336_num_7.txt
# 3336_num_8.txt
# 3336_num_9.txt
# 3336_num_10.txt
# 3336_num_11.txt
# 3336_num_12.txt
# 3336_num_13.txt
# 3336_num_14.txt
# 3336_num_15.txt
# 3336_num_16.txt
# 3336_num_17.txt
# 3336_num_18.txt
# 3336_num_19.txt
# 3336_num_20.txt
# 3336_num_21.txt
# 3336_num_22.txt
# 3336_num_23.txt
# 3336_num_24.txt
# 3336_num_25.txt
# 3336_num_26.txt
# 3336_num_27.txt
# 3336_num_28.txt
# 3336_num_29.txt
# 3337
# 3337_num_0.txt
# 3337_num_1.txt
# 3337_num_2.txt
# 3337_num_3.txt
# 3337_num_4.txt
# 3337_num_5.txt
# 3337_num_6.txt
# 3337_num_7.txt
# 3337_num_8.txt
# 3337_num_9.txt
# 3337_num_10.txt
# 3337_num_11.txt
# 3337_num_12.txt
# 3337_num_13.txt
# 3337_num_14.txt
# 3337_num_15.txt
# 3337_num_16.txt
# 3337_num_17.txt
# 3337_num_18.txt
# 3337_num_19.txt
# 3337_num_20.txt
# 3337_num_21.txt
# 3337_num_22.txt
# 3337_num_23.txt
# 3337_num_24.txt
# 3337_num_25.txt
# 3337_num_26.txt
# 3337_num_27.txt
# 3337_num_28.txt
# 3337_num_29.txt
# 3338
# 3338_num_0.txt
# 3338_num_1.txt
# 3338_num_2.txt
# 3338_num_3.txt
# 3338_num_4.txt
# 3338_num_5.txt
# 3338_num_6.txt
# 3338_num_7.txt
# 3338_num_8.txt
# 3338_num_9.txt
# 3338_num_10.txt
# 3338_num_11.txt
# 3338_num_12.txt
# 3338_num_13.txt
# 3338_num_14.txt
# 3338_num_15.txt
# 3338_num_16.txt
# 3338_num_17.txt
# 3338_num_18.txt
# 3338_num_19.txt
# 3338_num_20.txt
# 3338_num_21.txt
# 3338_num_22.txt
# 3338_num_23.txt
# 3338_num_24.txt
# 3338_num_25.txt
# 3338_num_26.txt
# 3338_num_27.txt
# 3338_num_28.txt
# 3338_num_29.txt
# 3339
# 3339_num_0.txt
# 3339_num_1.txt
# 3339_num_2.txt
# 3339_num_3.txt
# 3339_num_4.txt
# 3339_num_5.txt
# 3339_num_6.txt
# 3339_num_7.txt
# 3339_num_8.txt
# 3339_num_9.txt
# 3339_num_10.txt
# 3339_num_11.txt
# 3339_num_12.txt
# 3339_num_13.txt
# 3339_num_14.txt
# 3339_num_15.txt
# 3339_num_16.txt
# 3339_num_17.txt
# 3339_num_18.txt
# 3339_num_19.txt
# 3339_num_20.txt
# 3339_num_21.txt
# 3339_num_22.txt
# 3339_num_23.txt
# 3339_num_24.txt
# 3339_num_25.txt
# 3339_num_26.txt
# 3339_num_27.txt
# 3339_num_28.txt
# 3339_num_29.txt
# 3340
# 3340_num_0.txt
# 3340_num_1.txt
# 3340_num_2.txt
# 3340_num_3.txt
# 3340_num_4.txt
# 3340_num_5.txt
# 3340_num_6.txt
# 3340_num_7.txt
# 3340_num_8.txt
# 3340_num_9.txt
# 3340_num_10.txt
# 3340_num_11.txt
# 3340_num_12.txt
# 3340_num_13.txt
# 3340_num_14.txt
# 3340_num_15.txt
# 3340_num_16.txt
# 3340_num_17.txt
# 3340_num_18.txt
# 3340_num_19.txt
# 3340_num_20.txt
# 3340_num_21.txt
# 3340_num_22.txt
# 3340_num_23.txt
# 3340_num_24.txt
# 3340_num_25.txt
# 3340_num_26.txt
# 3340_num_27.txt
# 3340_num_28.txt
# 3340_num_29.txt
# 3341
# 3341_num_0.txt
# 3341_num_1.txt
# 3341_num_2.txt
# 3341_num_3.txt
# 3341_num_4.txt
# 3341_num_5.txt
# 3341_num_6.txt
# 3341_num_7.txt
# 3341_num_8.txt
# 3341_num_9.txt
# 3341_num_10.txt
# 3341_num_11.txt
# 3341_num_12.txt
# 3341_num_13.txt
# 3341_num_14.txt
# 3341_num_15.txt
# 3341_num_16.txt
# 3341_num_17.txt
# 3341_num_18.txt
# 3341_num_19.txt
# 3341_num_20.txt
# 3341_num_21.txt
# 3341_num_22.txt
# 3341_num_23.txt
# 3341_num_24.txt
# 3341_num_25.txt
# 3341_num_26.txt
# 3341_num_27.txt
# 3341_num_28.txt
# 3341_num_29.txt
# 3342
# 3342_num_0.txt
# 3342_num_1.txt
# 3342_num_2.txt
# 3342_num_3.txt
# 3342_num_4.txt
# 3342_num_5.txt
# 3342_num_6.txt
# 3342_num_7.txt
# 3342_num_8.txt
# 3342_num_9.txt
# 3342_num_10.txt
# 3342_num_11.txt
# 3342_num_12.txt
# 3342_num_13.txt
# 3342_num_14.txt
# 3342_num_15.txt
# 3342_num_16.txt
# 3342_num_17.txt
# 3342_num_18.txt
# 3342_num_19.txt
# 3342_num_20.txt
# 3342_num_21.txt
# 3342_num_22.txt
# 3342_num_23.txt
# 3342_num_24.txt
# 3342_num_25.txt
# 3342_num_26.txt
# 3342_num_27.txt
# 3342_num_28.txt
# 3342_num_29.txt
# 3343
# 3343_num_0.txt
# 3343_num_1.txt
# 3343_num_2.txt
# 3343_num_3.txt
# 3343_num_4.txt
# 3343_num_5.txt
# 3343_num_6.txt
# 3343_num_7.txt
# 3343_num_8.txt
# 3343_num_9.txt
# 3343_num_10.txt
# 3343_num_11.txt
# 3343_num_12.txt
# 3343_num_13.txt
# 3343_num_14.txt
# 3343_num_15.txt
# 3343_num_16.txt
# 3343_num_17.txt
# 3343_num_18.txt
# 3343_num_19.txt
# 3343_num_20.txt
# 3343_num_21.txt
# 3343_num_22.txt
# 3343_num_23.txt
# 3343_num_24.txt
# 3343_num_25.txt
# 3343_num_26.txt
# 3343_num_27.txt
# 3343_num_28.txt
# 3343_num_29.txt
# 3344
# 3344_num_0.txt
# 3344_num_1.txt
# 3344_num_2.txt
# 3344_num_3.txt
# 3344_num_4.txt
# 3344_num_5.txt
# 3344_num_6.txt
# 3344_num_7.txt
# 3344_num_8.txt
# 3344_num_9.txt
# 3344_num_10.txt
# 3344_num_11.txt
# 3344_num_12.txt
# 3344_num_13.txt
# 3344_num_14.txt
# 3344_num_15.txt
# 3344_num_16.txt
# 3344_num_17.txt
# 3344_num_18.txt
# 3344_num_19.txt
# 3344_num_20.txt
# 3344_num_21.txt
# 3344_num_22.txt
# 3344_num_23.txt
# 3344_num_24.txt
# 3344_num_25.txt
# 3344_num_26.txt
# 3344_num_27.txt
# 3344_num_28.txt
# 3344_num_29.txt
# 3345
# 3345_num_0.txt
# 3345_num_1.txt
# 3345_num_2.txt
# 3345_num_3.txt
# 3345_num_4.txt
# 3345_num_5.txt
# 3345_num_6.txt
# 3345_num_7.txt
# 3345_num_8.txt
# 3345_num_9.txt
# 3345_num_10.txt
# 3345_num_11.txt
# 3345_num_12.txt
# 3345_num_13.txt
# 3345_num_14.txt
# 3345_num_15.txt
# 3345_num_16.txt
# 3345_num_17.txt
# 3345_num_18.txt
# 3345_num_19.txt
# 3345_num_20.txt
# 3345_num_21.txt
# 3345_num_22.txt
# 3345_num_23.txt
# 3345_num_24.txt
# 3345_num_25.txt
# 3345_num_26.txt
# 3345_num_27.txt
# 3345_num_28.txt
# 3345_num_29.txt
# 3346
# 3346_num_0.txt
# 3346_num_1.txt
# 3346_num_2.txt
# 3346_num_3.txt
# 3346_num_4.txt
# 3346_num_5.txt
# 3346_num_6.txt
# 3346_num_7.txt
# 3346_num_8.txt
# 3346_num_9.txt
# 3346_num_10.txt
# 3346_num_11.txt
# 3346_num_12.txt
# 3346_num_13.txt
# 3346_num_14.txt
# 3346_num_15.txt
# 3346_num_16.txt
# 3346_num_17.txt
# 3346_num_18.txt
# 3346_num_19.txt
# 3346_num_20.txt
# 3346_num_21.txt
# 3346_num_22.txt
# 3346_num_23.txt
# 3346_num_24.txt
# 3346_num_25.txt
# 3346_num_26.txt
# 3346_num_27.txt
# 3346_num_28.txt
# 3346_num_29.txt
# 3347
# 3347_num_0.txt
# 3347_num_1.txt
# 3347_num_2.txt
# 3347_num_3.txt
# 3347_num_4.txt
# 3347_num_5.txt
# 3347_num_6.txt
# 3347_num_7.txt
# 3347_num_8.txt
# 3347_num_9.txt
# 3347_num_10.txt
# 3347_num_11.txt
# 3347_num_12.txt
# 3347_num_13.txt
# 3347_num_14.txt
# 3347_num_15.txt
# 3347_num_16.txt
# 3347_num_17.txt
# 3347_num_18.txt
# 3347_num_19.txt
# 3347_num_20.txt
# 3347_num_21.txt
# 3347_num_22.txt
# 3347_num_23.txt
# 3347_num_24.txt
# 3347_num_25.txt
# 3347_num_26.txt
# 3347_num_27.txt
# 3347_num_28.txt
# 3347_num_29.txt
# 3348
# 3348_num_0.txt
# 3348_num_1.txt
# 3348_num_2.txt
# 3348_num_3.txt
# 3348_num_4.txt
# 3348_num_5.txt
# 3348_num_6.txt
# 3348_num_7.txt
# 3348_num_8.txt
# 3348_num_9.txt
# 3348_num_10.txt
# 3348_num_11.txt
# 3348_num_12.txt
# 3348_num_13.txt
# 3348_num_14.txt
# 3348_num_15.txt
# 3348_num_16.txt
# 3348_num_17.txt
# 3348_num_18.txt
# 3348_num_19.txt
# 3348_num_20.txt
# 3348_num_21.txt
# 3348_num_22.txt
# 3348_num_23.txt
# 3348_num_24.txt
# 3348_num_25.txt
# 3348_num_26.txt
# 3348_num_27.txt
# 3348_num_28.txt
# 3348_num_29.txt
# 3349
# 3349_num_0.txt
# 3349_num_1.txt
# 3349_num_2.txt
# 3349_num_3.txt
# 3349_num_4.txt
# 3349_num_5.txt
# 3349_num_6.txt
# 3349_num_7.txt
# 3349_num_8.txt
# 3349_num_9.txt
# 3349_num_10.txt
# 3349_num_11.txt
# 3349_num_12.txt
# 3349_num_13.txt
# 3349_num_14.txt
# 3349_num_15.txt
# 3349_num_16.txt
# 3349_num_17.txt
# 3349_num_18.txt
# 3349_num_19.txt
# 3349_num_20.txt
# 3349_num_21.txt
# 3349_num_22.txt
# 3349_num_23.txt
# 3349_num_24.txt
# 3349_num_25.txt
# 3349_num_26.txt
# 3349_num_27.txt
# 3349_num_28.txt
# 3349_num_29.txt
# 3350
# 3350_num_0.txt
# 3350_num_1.txt
# 3350_num_2.txt
# 3350_num_3.txt
# 3350_num_4.txt
# 3350_num_5.txt
# 3350_num_6.txt
# 3350_num_7.txt
# 3350_num_8.txt
# 3350_num_9.txt
# 3350_num_10.txt
# 3350_num_11.txt
# 3350_num_12.txt
# 3350_num_13.txt
# 3350_num_14.txt
# 3350_num_15.txt
# 3350_num_16.txt
# 3350_num_17.txt
# 3350_num_18.txt
# 3350_num_19.txt
# 3350_num_20.txt
# 3350_num_21.txt
# 3350_num_22.txt
# 3350_num_23.txt
# 3350_num_24.txt
# 3350_num_25.txt
# 3350_num_26.txt
# 3350_num_27.txt
# 3350_num_28.txt
# 3350_num_29.txt
# 3351
# 3351_num_0.txt
# 3351_num_1.txt
# 3351_num_2.txt
# 3351_num_3.txt
# 3351_num_4.txt
# 3351_num_5.txt
# 3351_num_6.txt
# 3351_num_7.txt
# 3351_num_8.txt
# 3351_num_9.txt
# 3351_num_10.txt
# 3351_num_11.txt
# 3351_num_12.txt
# 3351_num_13.txt
# 3351_num_14.txt
# 3351_num_15.txt
# 3351_num_16.txt
# 3351_num_17.txt
# 3351_num_18.txt
# 3351_num_19.txt
# 3351_num_20.txt
# 3351_num_21.txt
# 3351_num_22.txt
# 3351_num_23.txt
# 3351_num_24.txt
# 3351_num_25.txt
# 3351_num_26.txt
# 3351_num_27.txt
# 3351_num_28.txt
# 3351_num_29.txt
# 3352
# 3352_num_0.txt
# 3352_num_1.txt
# 3352_num_2.txt
# 3352_num_3.txt
# 3352_num_4.txt
# 3352_num_5.txt
# 3352_num_6.txt
# 3352_num_7.txt
# 3352_num_8.txt
# 3352_num_9.txt
# 3352_num_10.txt
# 3352_num_11.txt
# 3352_num_12.txt
# 3352_num_13.txt
# 3352_num_14.txt
# 3352_num_15.txt
# 3352_num_16.txt
# 3352_num_17.txt
# 3352_num_18.txt
# 3352_num_19.txt
# 3352_num_20.txt
# 3352_num_21.txt
# 3352_num_22.txt
# 3352_num_23.txt
# 3352_num_24.txt
# 3352_num_25.txt
# 3352_num_26.txt
# 3352_num_27.txt
# 3352_num_28.txt
# 3352_num_29.txt
# 3353
# 3353_num_0.txt
# 3353_num_1.txt
# 3353_num_2.txt
# 3353_num_3.txt
# 3353_num_4.txt
# 3353_num_5.txt
# 3353_num_6.txt
# 3353_num_7.txt
# 3353_num_8.txt
# 3353_num_9.txt
# 3353_num_10.txt
# 3353_num_11.txt
# 3353_num_12.txt
# 3353_num_13.txt
# 3353_num_14.txt
# 3353_num_15.txt
# 3353_num_16.txt
# 3353_num_17.txt
# 3353_num_18.txt
# 3353_num_19.txt
# 3353_num_20.txt
# 3353_num_21.txt
# 3353_num_22.txt
# 3353_num_23.txt
# 3353_num_24.txt
# 3353_num_25.txt
# 3353_num_26.txt
# 3353_num_27.txt
# 3353_num_28.txt
# 3353_num_29.txt
# 3354
# 3354_num_0.txt
# 3354_num_1.txt
# 3354_num_2.txt
# 3354_num_3.txt
# 3354_num_4.txt
# 3354_num_5.txt
# 3354_num_6.txt
# 3354_num_7.txt
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/socks.py in connect(self, dest_pair)
#     793             # Initial connection to proxy server.
# --> 794             super(socksocket, self).connect(proxy_addr)
#     795
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ProxyConnectionError                      Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ~/anaconda3/lib/python3.6/site-packages/socks.py in wrapper(*args, **kwargs)
#      95                 self.setblocking(True)
# ---> 96             return function(*args, **kwargs)
#      97         except Exception as e:
#
# ~/anaconda3/lib/python3.6/site-packages/socks.py in connect(self, dest_pair)
#     805             log.debug("%s due to: %s", msg, error)
# --> 806             raise ProxyConnectionError(msg, error)
#     807
#
# ProxyConnectionError: Error connecting to SOCKS5 proxy localhost:9150: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x1109a6b38>: Failed to establish a new connection: Error connecting to SOCKS5 proxy localhost:9150: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='seekingalpha.com', port=443): Max retries exceeded with url: //article/776181-lincoln-national-management-discusses-q2-2012-results-earnings-call-transcript (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1109a6b38>: Failed to establish a new connection: Error connecting to SOCKS5 proxy localhost:9150: [Errno 61] Connection refused',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-8-d6b4bbc2dbb2> in <module>()
#       4     for x in range(0, len(arts)):
#       5         time.sleep(np.random.uniform(low=9, high=11))
# ----> 6         art_text = one_transcript_getter(arts[x])
#       7
#       8         with open(folder + "data/parsing/" + str(i) + '_num_' + str(x) + '.txt', "w") as f:
#
# <ipython-input-7-ff4b8b5deb96> in one_transcript_getter(art)
#       1 def one_transcript_getter(art):
#       2     h = generate_user_agent() #next(headers)
# ----> 3     page_art = requests.get(url_site + art, headers={'User-Agent': h})
#       4     if page_art.status_code==200:
#       5         page_bs_art = BeautifulSoup(page_art.text, "lxml")
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='seekingalpha.com', port=443): Max retries exceeded with url: //article/776181-lincoln-national-management-discusses-q2-2012-results-earnings-call-transcript (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1109a6b38>: Failed to establish a new connection: Error connecting to SOCKS5 proxy localhost:9150: [Errno 61] Connection refused',))

# %%
# from TorCrawler import TorCrawler
# crawler = TorCrawler(ctrl_pass='16:763D8381509BF7E6608DDAD0797412A305D2A0793AD74DB8B84F6CCEC8')
